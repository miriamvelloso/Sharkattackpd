# %%
#primero importo los modulos 
import pandas as pd
import numpy as np

# %%
#importo el archivo attacks y lo imprimo)
df = pd.read_csv('attacks.csv', encoding='latin-1')
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
#ver cuantas filas tiene el documento
df.shape
# Out:
# (25723, 24)

# %%
#empezaré a realizar mi analisis viendo en que filas tengo más información.
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 22               25722
# Unnamed: 23               25721
# Time                      22775
# Species                   22259
# Age                       22252
# Sex                       19986
# Activity                  19965
# Location                  19961
# Fatal (Y/N)               19960
# Area                      19876
# Name                      19631
# Country                   19471
# Injury                    19449
# Investigator or Source    19438
# Type                      19425
# Year                      19423
# href formula              19422
# pdf                       19421
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# Date                      19421
# original order            19414
# Case Number               17021
# dtype: int64

# %%
#filtro las columnas que me interesan para mi caso
new_df = df[["Name","Type","Country","Activity","Date"]]

# %%
new_df
# Out:
#                   Name        Type    Country     Activity         Date
# 0          Julie Wolfe     Boating        USA     Paddling  25-Jun-2018
# 1      Adyson McNeely   Unprovoked        USA     Standing  18-Jun-2018
# 2          John Denges     Invalid        USA      Surfing  09-Jun-2018
# 3                 male  Unprovoked  AUSTRALIA      Surfing  08-Jun-2018
# 4       Gustavo Ramos     Provoked     MEXICO  Free diving  04-Jun-2018
# ...                ...         ...        ...          ...          ...
# 25718              NaN         NaN        NaN          NaN          NaN
# 25719              NaN         NaN        NaN          NaN          NaN
# 25720              NaN         NaN        NaN          NaN          NaN
# 25721              NaN         NaN        NaN          NaN          NaN
# 25722              NaN         NaN        NaN          NaN          NaN
#
# [25723 rows x 5 columns]

# %%
transponer = np.transpose(new_df)
transponer
# Out:
#                 0                1            2            3      \
# Name      Julie Wolfe  Adyson McNeely   John Denges         male
# Type          Boating       Unprovoked      Invalid   Unprovoked
# Country           USA              USA          USA    AUSTRALIA
# Activity     Paddling         Standing      Surfing      Surfing
# Date      25-Jun-2018      18-Jun-2018  09-Jun-2018  08-Jun-2018
#
#                    4             5                       6            7      \
# Name      Gustavo Ramos        Chris
#   Jose Ernesto da Silva          male
# Type            Provoked    Unprovoked              Unprovoked   Unprovoked
# Country           MEXICO     AUSTRALIA                  BRAZIL          USA
# Activity     Free diving  Kite surfing                Swimming      Fishing
# Date         04-Jun-2018   03-Jun-2018             03-Jun-2018  27-May-2018
#
#                 8            9      ... 25713 25714 25715 25716 25717 25718  \
# ...

# %%
#al haber hecho el transponer veo que columnas tienen todos sus datos "Nan" y las elimino
transponer = new_df.drop_duplicates()
transponer
# Out:
#                        Name        Type             Country      Activity  \
# 0               Julie Wolfe     Boating                 USA      Paddling
# 1           Adyson McNeely   Unprovoked                 USA      Standing
# 2               John Denges     Invalid                 USA       Surfing
# 3                      male  Unprovoked           AUSTRALIA       Surfing
# 4            Gustavo Ramos     Provoked              MEXICO   Free diving
# ...                     ...         ...                 ...           ...
# 6298                  Ahmun  Unprovoked           AUSTRALIA  Pearl diving
# 6299  Coast Guard personnel  Unprovoked                 USA      Swimming
# 6300        Jules Patterson  Unprovoked              PANAMA           NaN
# 6301                   male  Unprovoked  CEYLON (SRI LANKA)      Swimming
# 6302                    NaN         NaN                 NaN           NaN
#
#              Date
# 0     25-Jun-2018
# 1     18-Jun-2018
# 2     09-Jun-2018
# ...

# %%
#eliminamos la ultima fila que no presenta ningun dato
estudio = transponer[0:6286]
estudio
# Out:
#                        Name        Type             Country      Activity  \
# 0               Julie Wolfe     Boating                 USA      Paddling
# 1           Adyson McNeely   Unprovoked                 USA      Standing
# 2               John Denges     Invalid                 USA       Surfing
# 3                      male  Unprovoked           AUSTRALIA       Surfing
# 4            Gustavo Ramos     Provoked              MEXICO   Free diving
# ...                     ...         ...                 ...           ...
# 6297                   male  Unprovoked           AUSTRALIA        Diving
# 6298                  Ahmun  Unprovoked           AUSTRALIA  Pearl diving
# 6299  Coast Guard personnel  Unprovoked                 USA      Swimming
# 6300        Jules Patterson  Unprovoked              PANAMA           NaN
# 6301                   male  Unprovoked  CEYLON (SRI LANKA)      Swimming
#
#              Date
# 0     25-Jun-2018
# 1     18-Jun-2018
# 2     09-Jun-2018
# ...

# %%
estudio.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# Activity    542
# Name        209
# Country      50
# Type          4
# Date          0
# dtype: int64

# %%
#Voy a ver cual es el pais que más ataques a tenido y parto mi analisis de este.
df.Country.value_counts()
# Out:
# USA                               2229
# AUSTRALIA                         1338
# SOUTH AFRICA                       579
# PAPUA NEW GUINEA                   134
# NEW ZEALAND                        128
#                                   ...
# NICARAGUA                            1
# CEYLON (SRI LANKA)                   1
# GABON                                1
# IRAN / IRAQ                          1
# FEDERATED STATES OF MICRONESIA       1
# Name: Country, Length: 212, dtype: int64

# %%
df.Activity.value_counts()
# Out:
# Surfing                                                                          971
# Swimming                                                                         869
# Fishing                                                                          431
# Spearfishing                                                                     333
# Bathing                                                                          162
#                                                                                 ...
# Holding shark on leader & dangling it above the water                              1
# Dived overboard & was swimming near stern of trawler                               1
# Removing shark from net                                                            1
# Swimming, attempting to rescue a girl  believed to be drowning                     1
# On life raft tethered to lifeboat. A seaman put hand over side to rinse a cup      1
# ...
